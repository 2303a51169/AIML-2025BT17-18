# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51169/AIML-2025BT17-18/blob/main/Assigment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Section 1
import numpy as np
import pandas as pd
my_list = [1, 2, 3, 4, 5]
print(my_list)
print(type(my_list))
my_array = np.array([1, 2, 3, 4, 5])
print(my_array)
print(type(my_array))
print(type(my_list))
print(type(my_array))
result = my_array * 2
print(result)
result = my_array / 2
print(result)
result = my_array ** 2
print(result)
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])
result = array1 + array2
print("Addition of Two: ", result)
import numpy as np
x = np.array([1, 2, 3, 4, 5])
result = np.sin(x)
print(result)
result = np.log(x)
print(result)
result = np.log2(x)
print(result)
result = np.exp(x)
print(result)
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'numpy.ndarray'>
# [ 2  4  6  8 10]
# [0.5 1.  1.5 2.  2.5]
# [ 1  4  9 16 25]
# Addition of Two:  [5 7 9]
# [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# [0.         0.69314718 1.09861229 1.38629436 1.60943791]
# [0.         1.         1.5849625  2.         2.32192809]
# [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]

# %%
#Section 2
import matplotlib.pyplot as plt
people = ['Kiran', 'Arun', 'Vijay', 'Varun']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]
plt.scatter(height, weight)
plt.title('Scatter Plot of Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()
plt.bar(people, age)
plt.title('Bar Chart of Age Distribution')
plt.xlabel('Person')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.show()
plt.hist(weight, bins=5, edgecolor='black')
plt.title('Histogram of Weight Distribution')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.show()
